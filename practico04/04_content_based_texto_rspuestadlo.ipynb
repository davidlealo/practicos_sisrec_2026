# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/practicos_sisrec_2026/blob/main/practico04/04_content_based_texto_rspuestadlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctico Content-based (Texto)
#
# **Profesor:** Denis Parra
#
# **Alumno:** `David Leal`
#
#
# En este proyecto trabajaremos con un modelo de recomendacion de libros de la página [Goodreads](http://www.goodreads.com). El modelo de recomendación de libros es un recomendador basado en contenido, donde se utilizan modelos de lenguage BERT y BERT-large para el cálculo de embeddings de los libros y luego similaridades de ítems. Luego, dependiendo de los libros con los que el usuario ha interactuado, se recomiendan los ítems más similares.

# %%
import numpy as np
import json
import requests
import heapq
import math
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from sklearn.decomposition import PCA
from io import BytesIO
import pickle
import pandas as pd
import time

# %% [markdown]
# Descargamos datos que vienen previamente calculados:
# - transacciones/interacciones de cada usuario
# - transaciones para evaluar el modelo
# - embeddings de descripciones calculados con BERT
# - embeddings de descripciones calculados con BERT-large
# - datos de libros con información de titulo, descripcion, año de publicacion, entre otros.

# %%
# !wget https://www.dropbox.com/s/57tel5zqopkssrh/books.csv?dl=0 -O books.csv
# !wget https://www.dropbox.com/s/zpnnoy1i8ljf9fg/goodreads_bert_embeddings.npy?dl=0 -O goodreads_bert_embeddings.npy
# !wget https://www.dropbox.com/s/a8hcc9w30y7r3jl/goodreads_bert_large_embeddings.npy?dl=0 -O goodreads_bert_large_embeddings.npy
# !wget https://www.dropbox.com/s/dqeqpsr0vdvmcy0/goodreads_past_interactions.json?dl=0 -O goodreads_past_interactions.json
# !wget https://www.dropbox.com/s/rjtzhmb2zbpp30q/goodreads_test_interactions.json?dl=0 -O goodreads_test_interactions.json
# Out:
# --2026-04-03 15:16:03--  https://www.dropbox.com/s/57tel5zqopkssrh/books.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/5s6xrfnu17yi34sfhmskb/books.csv?rlkey=ymzokbyqw3qq2bq5okfao9w1z&dl=0 [following]
# --2026-04-03 15:16:03--  https://www.dropbox.com/scl/fi/5s6xrfnu17yi34sfhmskb/books.csv?rlkey=ymzokbyqw3qq2bq5okfao9w1z&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com/cd/0/inline/C95UG99hFJtozJ3k5NBPViqRfE9NG0V3MFD-qZk1zMaBFi0aj4d7NXGGFXPt3dW6dU22gSDfG6JZai1kwPBDoDvH-Z99qvjLRv5fGrSUr0SW5iOto3LJIikGrDx_J082R0qDFC5uX1GlHXd57IjfYjS5/file# [following]
# --2026-04-03 15:16:03--  https://uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com/cd/0/inline/C95UG99hFJtozJ3k5NBPViqRfE9NG0V3MFD-qZk1zMaBFi0aj4d7NXGGFXPt3dW6dU22gSDfG6JZai1kwPBDoDvH-Z99qvjLRv5fGrSUr0SW5iOto3LJIikGrDx_J082R0qDFC5uX1GlHXd57IjfYjS5/file
# Resolving uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com (uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com (uc7a8576e3972baff33bb4ee0dc5.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 
dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com/cd/0/inline/C95gkhZPK4qwSavEfR4cNAHl1LI4-SSrEpE7j7cB-l-Rc85XqknuS8dwF4P0AxTO8f5YFncJvplEcVFh1NN4QQ_9k1Bdt8yiWbbKCdIBD6N0k82UEWTzJlaqaqILAtMYnGxtEM3WiV6mTzkzymgfNi3I/file# [following]
# --2026-04-03 15:16:10--  https://uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com/cd/0/inline/C95gkhZPK4qwSavEfR4cNAHl1LI4-SSrEpE7j7cB-l-Rc85XqknuS8dwF4P0AxTO8f5YFncJvplEcVFh1NN4QQ_9k1Bdt8yiWbbKCdIBD6N0k82UEWTzJlaqaqILAtMYnGxtEM3WiV6mTzkzymgfNi3I/file
# Resolving uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com (uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com (uc1c246ac28fd9580ead55245c67.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6111 (6.0K) [text/plain]
# Saving to: ‘goodreads_test_interactions.json’
#
# goodreads_test_inte 100%[===================>]   5.97K  --.-KB/s    in 0s
#
# 2026-04-03 15:16:10 (2.14 GB/s) - ‘goodreads_test_interactions.json’ saved [6111/6111]

# %% [markdown]
# # Cargar datos adicionales

# %%
df_books = pd.read_csv('books.csv', sep=',')
df_books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... work_ratings_count  \
# 0                          The Hunger Games  ...            4942365
# 1  Harry Potter and the Philosopher's Stone  ...            4800065
# 2                                  Twilight  ...            3916824
# 3                     To Kill a Mockingbird  ...            3340896
# 4                          The Great Gatsby  ...            2773745
#
#   work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 0                  155254      66715     127936     560092    1481305
# 1                   75867      75504     101676     455024    1156318
# 2                   95009     456191     436802     793319     875073
# 3                   72586      60427     117415     446835    1001952
# 4                   51992      86236     197621     606158     936012
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
# 3    1714267  https://images.gr-assets.com/books/1361975680m...
# 4     947718  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#                                            book_desc
# 0  Winning will make you famous. Losing means cer...
# 1  Harry Potter's life is miserable. His parents ...
# 2  About three things I was absolutely positive.F...
# 3  The unforgettable novel of a childhood in a sl...
# 4  Alternate Cover Edition ISBN: 0743273567 (ISBN...
#
# [5 rows x 24 columns]

# %%
df_books.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'book_desc'],
#       dtype='object')

# %%
print("# ítems   --> ", df_books["book_id"].nunique())
# Out:
# # ítems   -->  4287

# %%
# diccionario con id del usuario y id de libros con los que ha interactuado en el pasado
with open('goodreads_past_interactions.json') as f:
    user_interactions = json.load(f)

# diccionario con id del usuario y id de libros para testear el modelo
with open('goodreads_test_interactions.json') as f:
    user_interactions_test = json.load(f)

# %%
# dict index 2 book id and vice-versa for recommendation
idx2bookid = {i: id_ for i, id_ in enumerate(df_books.book_id)}
bookid2idx = {id_:i for i, id_ in enumerate(df_books.book_id)}

# %% [markdown]
# # Cargar características pre-entrenadas: BERT y BERT-large
#
# En esta sección se trabajará con modelos pre-entrenados de modelos de lenguage BERT y BERT-large que convierten texto a embeddings.
#
# Bidirectional Encoder Representations from Transformers (BERT) es una técnica de NLP (Natural Language Processing) desarrollada por Google y publicada en 2018 por Jacob Devlin.
#
# Actualmente Google utiliza BERT para entender las consultas de los usuarios en su buscador.
#
# Tiene dos versiones:
# - **BERT:** 12 capas, 12 cabezales de atencion y 110 millones de parámetros. Genera vectores de 768 dimensiones
# - **BERT-large:** 24 capas, 16 cabezales de atencion y 340 millones de parámetros. Genera vectores de 1024 dimensiones
#
# ![BERT y BERT-large](http://jalammar.github.io/images/bert-base-bert-large.png)
#
# ![BERT y BERT-large arquitectura](http://jalammar.github.io/images/bert-base-bert-large-encoders.png)
#
# En este caso los textos que utilizaremos son los títulos de los libros con su descripción y compararemos los resultados de recomendación con BERT y BERT-large. Para efectos de este trabajo los vectores de características ya fueron entrenados y guardados en archivos numpy. A continuación son cargados en memoria.
#
# Para mayores detalles sobre el modelo de lenguaje BERT se recomienda revisar el siguiente artículo:
# - [BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805.pdf)

# %%
bert_featmat = np.load('goodreads_bert_embeddings.npy', allow_pickle=True)
bert_large_featmat = np.load('goodreads_bert_large_embeddings.npy', allow_pickle=True)

# %%
bert_featmat.shape
# Out:
# (4287, 768)

# %%
bert_large_featmat.shape
# Out:
# (4287, 1024)

# %% [markdown]
# ### **Pregunta 1**
#
# Considerando que haremos un recomendador basado en contenidos ¿Por qué el uso de modelos de lenguage es una buena elección para este tipo de problema?

# %% [markdown]
# **Respuesta 1:**
#
# Algo de esto hablamos en la última clase. Por un lado los modelos BOW toman el supuesto que la frecuencia y las operaciones que podamos hacer con ella son las relevantes y no el orden de las palabras, pero eso no parece estar muy relacionado con la comprensión del lenguaje. Yo so cambio completamente el orden de una oración o un libro completo puedo tener resultados muy distintos, incluso existen libros que sin cambiar el orden de las palabras, pero sí de los capítulos los resultados son diferentes. El ejemplo que creo es más conocido es Rayuela de Julio Cortazar.
#
# Por lo tanto, procesar con PLN es lo correcto, pero los modelos de lenguaje como Bert, GPT, etc nos permiten mantener también el orden y con esto poder hacer otro tipo de acciones con mejor performance, aunque se sabe que los modelos tipo BOW como IT-IDF para temas como búsqueda no son necesariamente malos.
#
# Entonces, en este caso que queremos que el modelo "comprenda" mejor los textos para la recomendación, usar Bert parece correcto y mejor que solamente ver la frecuencia.

# %% [markdown]
# # Probamos con BERT y BERT-large reduciendo dimensionalidad con PCA-20
#
# Una vez calculado (o cargado) los vectores característicos de cada libro a partir de su titulo y descripción, reducimos dimensionalidad. Probaremos con BERT y BERT-large para comparar los resultados de ambos en recomendación basada en contenido.

# %%
# Project into a 20 PCA feature space
pca20_bert_featmat = PCA(n_components=20).fit_transform(bert_featmat)
pca20_bert_large_featmat = PCA(n_components=20).fit_transform(bert_large_featmat)

# %%
pca20_bert_featmat.shape
# Out:
# (4287, 20)

# %%
pca20_bert_large_featmat.shape
# Out:
# (4287, 20)

# %% [markdown]
# ### **Pregunta 2**
#
# Comente por qué se utiliza PCA para reducir la dimensión de cada vector característico. ¿Qué sucede con la pérdida de información en la reducción de dimensionalidad?

# %% [markdown]
# **Respuesta 2:**
#
# Como Bert genera unos embeddings con unos vectores largos, el modelo cae en maldición de la dimensionalidad, entonces es recomendable reducir las dimensiones como lo hacemos con los modelos que vimos en clases anteriores, por ejemplo los implícitos o de ranking. En este caso se usa la técnica de PCA que es una de las usadas para esta labor.
#
# En este caso, el PCA hace una operación que reduce las dimensionalidades aumentando la representación de las características que mejor definen, en este caso el texto, y aunque perdemos información, la relación mejora de cómputo con esta pérdida es conveniente para poder realizar esta operación. Con esto se capta una mayor variabilidad del texto, en menos características.
#
# En clases se explicó que al hacer un proceso similar a FunkSVD puede elegir las características principales reduciendo el impacto de perder información y mejorando la performance del modelo. Aunque claro FunkSVD se usa cuando tenemos datos faltantes y PCA cuando tenemos la matriz completa. PCA, al igual que las descomposiciones matriciales vistas en recomendación, busca una representación latente que captura la mayor varianza, por lo tanto comprendiendo lo que diferencia a los datos encontrados.

# %% [markdown]
# # Similar document retrieval
#
# En esta sección utilizaremos los vectores cargados para hacer un sistema de recuperación o búsqueda de información, para diferentes métricas de distancia.
#
# Buscamos libros similares de acuerdo a la representación vectorial (BERT) de su título y descripción.

# %%
# format results
pd.options.display.max_colwidth = 50 # ...máximo de columna

# %%
# Find similar images by image id
def find_similar_books(embedding, query_id=None, metric='euclidean', topk=10):

    n = embedding.shape[0]

    if query_id is None:
        query_i = np.random.randint(n)
        query_id = idx2bookid[query_i]

    else:
        query_i = bookid2idx[query_id]


    distances = pairwise_distances(embedding[query_i].reshape(1,-1), embedding, metric=metric)
    heap = []
    for i in range(n):
        if len(heap) < topk:
            heapq.heappush(heap, (-distances[0][i], i))
        else:
            heapq.heappushpop(heap, (-distances[0][i], i))

    heap.sort(reverse=True)
    rec_ids = [idx2bookid[i] for _,i in heap]

    return rec_ids

# %% [markdown]
# ## Usando BERT

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine"
similar_books = find_similar_books(bert_featmat, query_id = 3, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [3, 2908, 3115, 2303, 7334, 7235, 5721, 3510, 9552, 9696]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id                                    original_title  \
# 2           3                                          Twilight
# 1423     2303                                      Bloody Bones
# 1708     2908                      Severed Heads, Broken Hearts
# 1808     3115                            A Hunger Like No Other
# 1999     3510  Cerulean Sins (Anita Blake, Vampire Hunter, #11)
# 2903     5721                                No Humans Involved
# 3423     7235                                         Afterburn
# 3459     7334                                     Graffiti Moon
# 4152     9552                                 The Last Werewolf
# 4198     9696                                    Perfect Shadow
#
#                                               book_desc              authors
# 2     About three things I was absolutely positive.F...      Stephenie Meyer
# 1423  In Laurell K. Hamilton's "New York Times" best...  Laurell K. Hamilton
# 1708  Robyn Schneider's The Beginning of Everything ...      Robyn Schneider
# 1808  In New York Times and USA TODAY bestselling au...         Kresley Cole
# 1999  Cerulean Sins, the eleventh entry in the hugel...  Laurell K. Hamilton
# 2903  In her acclaimed Women of the Otherworld serie...     Kelley Armstrong
# 3423  #1 New York Times bestselling author Sylvia Da...           Sylvia Day
# 3459  Lucy is in love with Shadow, a mysterious graf...         Cath Crowley
# 4152  Here is a powerful, definitive new version of ...          Glen Duncan
# 4198  Discover the origins of Durzo Blint in this or...          Brent Weeks

# %% [markdown]
# ## Usando BERT reducidos con PCA

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine"
similar_books = find_similar_books(pca20_bert_featmat, query_id = 3, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [3, 1354, 2908, 1886, 476, 2041, 7235, 9552, 4754, 6011]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id                                     original_title  \
# 2           3                                           Twilight
# 354       476                        The World According to Garp
# 919      1354  The Strange Case of Dr. Jekyll and Mr. Hyde an...
# 1201     1886                     Preacher Vol. 1: Gone to Texas
# 1289     2041                                      Lisey's Story
# 1708     2908                       Severed Heads, Broken Hearts
# 2524     4754                                     Midnight Bayou
# 3009     6011  What Do You Care What Other People Think? Furt...
# 3423     7235                                          Afterburn
# 4152     9552                                  The Last Werewolf
#
#                                               book_desc  \
# 2     About three things I was absolutely positive.F...
# 354   This is the life and times of T. S. Garp, the ...
# 919   \r\r\r\r\r\r\n'He put the glass to his lips an...
# 1201  One of the most celebrated comics titles of th...
# 1289  Lisey Landon lost her husband Scott two years ...
# 1708  Robyn Schneider's The Beginning of Everything ...
# 2524  #1 New York Times bestselling author Nora Robe...
# 3009  One of the greatest physicists of the twentiet...
# 3423  #1 New York Times bestselling author Sylvia Da...
# 4152  Here is a powerful, definitive new version of ...
#
#                                          authors
# 2                                Stephenie Meyer
# 354                                  John Irving
# 919       Robert Louis Stevenson, Robert Mighall
# 1201  Garth Ennis, Steve Dillon, Joe R. Lansdale
# 1289                                Stephen King
# 1708                             Robyn Schneider
# 2524                                Nora Roberts
# 3009                             Richard Feynman
# 3423                                  Sylvia Day
# 4152                                 Glen Duncan

# %% [markdown]
# ## Usando BERT-large

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine"
similar_books = find_similar_books(bert_large_featmat, query_id = 3, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [3, 7818, 712, 5118, 1818, 7221, 2112, 7101, 8266, 7552]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id                              original_title  \
# 2           3                                    Twilight
# 527       712             Drums of Autumn (Outlander, #4)
# 1160     1818                       One Foot in the Grave
# 1321     2112                       P.S. I Still Love You
# 2672     5118                                 Stars Above
# 3380     7101                                Magic Shifts
# 3421     7221                                  Eeny Meeny
# 3532     7552  The Dirty Life: On Farming, Food, and Love
# 3630     7818                                 Frostbitten
# 3764     8266                                   Bloodlust
#
#                                               book_desc  \
# 2     About three things I was absolutely positive.F...
# 527   In this breathtaking novel—rich in history and...
# 1160  You can run from the grave, but you can’t hide...
# 1321  Lara Jean didn’t expect to really fall for Pet...
# 2672  The enchantment continues....The universe of t...
# 3380  In the latest Kate Daniels novel from #1 New Y...
# 3421  The "dark, twisted, thought-provoking" (#1 New...
# 3532  "This book is the story of the two love affair...
# 3630  Smart, sexy, supernatural—the men and women of...
# 3764  \r\r\r\r\r\r\nA new beginning...\r\r\r\r\r\r\n...
#
#                                        authors
# 2                              Stephenie Meyer
# 527                             Diana Gabaldon
# 1160                            Jeaniene Frost
# 1321                                 Jenny Han
# 2672                             Marissa Meyer
# 3380                             Ilona Andrews
# 3421                              M.J. Arlidge
# 3532                           Kristin Kimball
# 3630                          Kelley Armstrong
# 3764  L.J. Smith, Kevin Williamson, Julie Plec

# %% [markdown]
# ## Usando BERT-large reducidos con PCA

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine"
similar_books = find_similar_books(pca20_bert_large_featmat, query_id = 3, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [3, 1818, 6977, 3984, 3549, 7818, 7221, 2476, 2483, 3408]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id                                     original_title  \
# 2           3                                           Twilight
# 1160     1818                              One Foot in the Grave
# 1492     2476                                     The Winter Sea
# 1496     2483                                               Rush
# 1944     3408                                     Hunting Ground
# 2019     3549                                              Fever
# 2199     3984                                The Darkest Whisper
# 3344     6977  The Mortal Instrument Series: City of Bones / ...
# 3421     7221                                         Eeny Meeny
# 3630     7818                                        Frostbitten
#
#                                               book_desc  \
# 2     About three things I was absolutely positive.F...
# 1160  You can run from the grave, but you can’t hide...
# 1492  In the spring of 1708, an invading Jacobite fl...
# 1496  Gabe, Jace, and Ash: three of the wealthiest, ...
# 1944  Anna Latham didn’t know how complicated life c...
# 2019  Jace, Ash, and Gabe: three of the wealthiest, ...
# 2199  New York Times bestselling sensation Gena Show...
# 3344  The Shadowhunters—touched by angels and charge...
# 3421  The "dark, twisted, thought-provoking" (#1 New...
# 3630  Smart, sexy, supernatural—the men and women of...
#
#                                authors
# 2                      Stephenie Meyer
# 1160                    Jeaniene Frost
# 1492  Susanna Kearsley, Rosalyn Landor
# 1496                        Maya Banks
# 1944                   Patricia Briggs
# 2019                        Maya Banks
# 2199                    Gena Showalter
# 3344                   Cassandra Clare
# 3421                      M.J. Arlidge
# 3630                  Kelley Armstrong

# %% [markdown]
# ### Pregunta 3:
# Comente los resultados obtenidos, en cuanto a modelo de lenguaje, reduccion de dimensionalidad y métrica de distancia utilizada.

# %% [markdown]
# **Respuesta 3:**
#
# Con Bert los resultados estaban más apegados a la palabra clave o concepto central de historias de vampiros, entonces hace una buena búsqueda pero poco variada, esto lo hablamos en algunas clases del peligro de ser un poco monotemáticos en las recomendaciones.
#
# Cuando le sumamos PCA a Bert se encuentra un poco más de variedad de títulos con temáticas de libros, por ejemplo terror y ya aparecen títulos son vampiros "The Strange Case of Dr. Jekyll and Mr. Hyde" y otras temñaticas más introspectivas de estas novelas adolescentes (tal vez mejor tratadas) con temáticas como el amor y los origenes de la creatividad como en Lisey's Story (busqué las obras, en este caso comparto el de wikipedia de esta última https://es.wikipedia.org/wiki/La_historia_de_Lisey)
#
# Cuando usamos Bert Large para algo interesante porque las recomendaciones están relaconados con los temas de aventuras, amor y libros que buscan ese contacto emocional que pueden tener los fanáticos de Twilight con sus personajes, pero en mi búsqueda de cada título en ninguno encontré personajes sobrenaturales de vampiros o hombres lobo (que son los que aparecen en Twilight), entonces fue una búsqueda que se centra más en el contenido emocional que en repetir personajes.
#
# Por último al sumar PCA a Bert Large por primera vez repetimos un autor y encontramos dos libros de una trología de Maya Banks. También en los primeros lugares encontramos un libro que había aparecido en la recomendación anterior de Bert Large que es One Foot in the Grave, cosa que no pasó con el Bert y Bert + PCA anterior. Entonces siento que es una recomendación más cercana a la que realizaría una persona especialista, más coherente con el tema temático que ya lo teníamos en Bert Large pero pudiendo recomendar literatura como uno lo hace, si te gustó X libro lee otro del mismo autor o uno que hable de los mismos temas.

# %% [markdown]
# # Recomendaciones

# %%
# format results
pd.options.display.max_colwidth = 50
#pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Función para obtener recomendacion para cada usuario

# %%
def recommend(embedding, user_id=None, topk=10, metric='cosine'):

    #print("user_id = ", user_id)

    user_id = str(user_id)

    #Calculate distance metrics
    trx = user_interactions[user_id]
    n = embedding.shape[0]
    distances = 1e9

    # recorremos transacciones pasadas del usuario
    for t in trx:
        query_i = bookid2idx[t]

        # recomendamos items más cercanos a items con los que interactuó el usuario
        distances = np.minimum(distances, pairwise_distances(
                embedding[query_i].reshape(1,-1), embedding, metric=metric).reshape(-1))

    #Rank items de menor a mayor distancia (nos quedamos con los topk)
    trx_set = set(trx)
    heap = []
    for i in range(n):
        if idx2bookid[i] in trx_set:
            continue
        if len(heap) < topk:
            heapq.heappush(heap, (-distances[i], i))
        else:
            heapq.heappushpop(heap, (-distances[i], i))
    heap.sort(reverse=True)

    # utilizamos un heap para extraer los items ordenados de menor a mayor distancia
    recommended_ids = [idx2bookid[i] for _,i in heap]

    # retornar los que el usuario no haya consumido
    filtered_recommended_ids = []

    return recommended_ids

# %% [markdown]
# ## Generar recomendaciones para un usuario en particular

# %%
# recomendación para el usuario id = 49299 , utilizando bert con reduccion de dimensionalidad a 20
user_id = '50101'
rec = recommend(pca20_bert_featmat, user_id=user_id, topk=15)
rec
# Out:
# [4509,
#  5002,
#  4376,
#  964,
#  2292,
#  7937,
#  5126,
#  9473,
#  5244,
#  390,
#  6219,
#  7602,
#  7913,
#  6865,
#  2796]

# %% [markdown]
# ## Transacciones pasadas del usuario

# %%
past_interactions = user_interactions[str(user_id)]

df_books[df_books['book_id'].isin(past_interactions)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id          original_title  \
# 2           3                Twilight
# 5           6  The Fault in Our Stars
# 7           8  The Catcher in the Rye
# 8          10     Pride and Prejudice
# 9          11        The Kite Runner
# ...       ...                     ...
# 2344     4323                El Deafo
# 2804     5476           The Crossover
# 3004     5992               Ball Four
# 3703     8057   Absent in the Spring
# 4170     9611           All Fall Down
#
#                                               book_desc  \
# 2     About three things I was absolutely positive.F...
# 5     Despite the tumor-shrinking medical miracle th...
# 7     The hero-narrator of The Catcher in the Rye is...
# 8     «È cosa ormai risaputa che a uno scapolo in po...
# 9      “It may be unfair, but what happens in a few ...
# ...                                                 ...
# 2344  Starting at a new school is scary, even more s...
# 2804  "With a bolt of lightning on my kicks . . .The...
# 3004  Twentieth-anniversary edition of a baseball cl...
# 3703  Returning from a visit to her daughter in Iraq...
# 4170  A new series of global proportions -- from mas...
#
#                                authors
# 2                      Stephenie Meyer
# 5                           John Green
# 7                        J.D. Salinger
# 8                          Jane Austen
# 9                      Khaled Hosseini
# ...                                ...
# 2344            Cece Bell, David Lasky
# 2804                   Kwame Alexander
# 3004                        Jim Bouton
# 3703  Mary Westmacott, Agatha Christie
# 4170                       Ally Carter
#
# [109 rows x 4 columns]

# %% [markdown]
# ## Información de recomendaciones

# %%
df_books[df_books['book_id'].isin(rec)][['book_id', 'original_title', 'book_desc', 'authors']]
# Out:
#       book_id                                     original_title  \
# 293       390          The Strange Case of Dr Jekyll and Mr Hyde
# 683       964               The Hobbit and The Lord of the Rings
# 1417     2292                         ساق البامبو [Saq al-Bambu]
# 1643     2796                                      The Lost Wife
# 2363     4376                                             شيكاجو
# 2418     4509                                               2666
# 2629     5002                         في ديسمبر تنتهي كل الأحلام
# 2676     5126                         Travesuras de la niña mala
# 2718     5244                                 Il barone rampante
# 3092     6219  Hyperspace: A Scientific Odyssey Through Paral...
# 3307     6865                                     The Gun Seller
# 3550     7602                                               Caim
# 3658     7913                                          La tregua
# 3664     7937     باب الخروج: رسالة علي المفعمة ببهجة غير متوقعة
# 4127     9473                                             Maktub
#
#                                               book_desc  \
# 293   Un abogado, Gabriel John Utterson, investiga l...
# 683   لجزء الثالث من ملحمة جيه أر أر تولكين الرائعة ...
# 1417  لماذا كان جلوسي تحت الشجرة يزعج أمي؟ أتراها كا...
# 1643  Praga, 1938. Lenka, una joven estudiante de ar...
# 2363  يقول الأستاذ جلال أمين عن هذه الرواية المتميزة...
# 2418  A cuatro profesores de literatura, Pelletier, ...
# 2629  أنا مُكتئب , مُكتئب جداً ! .. وعادة لا تُصيبني...
# 2676  ¿Cuál es el verdadero rostro del amor?Ricardo ...
# 2718  Cuando tenía doce años, Cosimo Piovasco, barón...
# 3092  ¿Hay otras dimensiones más allá de las de nues...
# 3307  Thomas Lang es un ex policía y ahora pistolero...
# 3550  Neste novo romance, o vencedor do prêmio Nobel...
# 3658  De las varias y buenas novelas de Mario Benede...
# 3664  عزيزي يحيى: اليوم هو العشرين من أكتوبر 2020، و...
# 4127  Maktub não é um livro de conselhos, mas uma tr...
#
#                                                 authors
# 293   Robert Louis Stevenson, Vladimir Nabokov, Merv...
# 683                                      J.R.R. Tolkien
# 1417                      سعود السنعوسي, Saud Alsanousi
# 1643                                     Alyson Richman
# 2363                      Alaa Al Aswany, علاء الأسواني
# 2418                                     Roberto Bolaño
# 2629                                أثير عبدالله النشمي
# 2676                                 Mario Vargas Llosa
# 2718                 Italo Calvino, Archibald Colquhoun
# 3092                                        Michio Kaku
# 3307                                        Hugh Laurie
# 3550                                      José Saramago
# 3658                                    Mario Benedetti
# 3664                                  عزالدين شكري فشير
# 4127                                       Paulo Coelho

# %% [markdown]
# # Evaluación de las recomendaciones con interacciones de testing

# %%
# Métricas de evaluación
# Obtenido de https://gist.github.com/bwhite/3726239

def precision_at_k(r, k):
    assert k >= 1
    r = np.asarray(r)[:k] != 0
    if r.size != k:
        raise ValueError('Relevance score length < k')
    return np.mean(r)

def average_precision(r):
    r = np.asarray(r) != 0
    out = [precision_at_k(r, k + 1) for k in range(r.size) if r[k]]
    if not out:
        return 0.
    return np.mean(out)

def mean_average_precision(rs):
    return np.mean([average_precision(r) for r in rs])

def dcg_at_k(r, k):
    r = np.asarray(r)[:k]
    if r.size:
        return np.sum(np.subtract(np.power(2, r), 1) / np.log2(np.arange(2, r.size + 2)))
    return 0.


def ndcg_at_k(r, k):
    idcg = dcg_at_k(sorted(r, reverse=True), k)

    if not idcg:
        return 0.
    return dcg_at_k(r, k) / idcg

# %% [markdown]
# ## Evaluación de recomendación con BERT

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

embeddings = pca20_bert_featmat
topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(bert_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.03669047619047619
# ndcg@10 0.13
# tiempo de ejecucion 270.85 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT reducidos con PCA-20

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

embeddings = pca20_bert_featmat
topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(pca20_bert_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.00453968253968254
# ndcg@10 0.03
# tiempo de ejecucion 13.18 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT-large

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.060920634920634924
# ndcg@10 0.24
# tiempo de ejecucion 487.36 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT-large reducidos con PCA-20

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(pca20_bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.026123015873015874
# ndcg@10 0.07
# tiempo de ejecucion 13.11 segs

# %% [markdown]
# ### Pregunta 4:
# - Comente los resultados en términos de tiempo de ejecución y métricas de ranking para los 4 modelos.

# %% [markdown]
# **Respuesta 4:**
#
# Es claro que al reducir dimensionalidades la reducción de tiempo de ejecución es claro, pero por lo menos en los resultados se pierde mucho en las métricas de relevancia. Tanto Bert como Bert Large tienen las mejores métricas en MAP y en nDCG. Al reducir dimensionalidades ganamos mucho tiempo (es muy grande la diferencia de 487.36 segs a 13.11 segs) bajando la precisión (aunque no en la misma proporción), de esta forma tal vez, en caso de necesitar mejorar los tiempos de cómputo, el oficio está en buscar el número de PCA que vamos a buscar, en este caso eran 20 entonces se podría subir un poco perdiendo menos en el resultado. Voy a hacer el experimento:

# %%
# Project into a 40 PCA feature space
pca40_bert_featmat = PCA(n_components=40).fit_transform(bert_featmat)

# %%
pca40_bert_featmat.shape
# Out:
# (4287, 40)

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(pca40_bert_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.018373015873015874
# ndcg@10 0.05
# tiempo de ejecucion 21.06 segs

# %%
# Project into a 40 PCA feature space
pca40_bert_large_featmat = PCA(n_components=40).fit_transform(bert_large_featmat)

# %%
pca40_bert_large_featmat.shape
# Out:
# (4287, 40)

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(pca40_bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.016123015873015872
# ndcg@10 0.07
# tiempo de ejecucion 17.06 segs

# %% [markdown]
# Hice el experimento y en Ber con PCA40 mejoró sin cambiar mucho el tiempo, pero en Bert Large + PCA40 se demoró lo mismo sin cambio en nDCG, entonces al parecer ahí la cantidad de PCA debería ser mayor

# %%
# Project into a 100 PCA feature space
pca100_bert_large_featmat = PCA(n_components=100).fit_transform(bert_large_featmat)

# %%
pca100_bert_large_featmat.shape
# Out:
# (4287, 100)

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10

for i, u in enumerate(user_interactions_test.keys()):

    print(i, end= '\r')

    rec = recommend(pca100_bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.02262301587301587
# ndcg@10 0.07
# tiempo de ejecucion 30.45 segs

# %% [markdown]
# Quedé con la idea que se sobre-entrenó porque el cambio es mínimo y el nDCG sigue sin modificarse.

# %% [markdown]
# # Uso de IA
#
# En este caso no usé IA lo que si hice fue buscar los libros en google y me iba leyendo las reseñas rápidas para tratar de comprender de qué trataban

# %% [markdown]
# Fue dejando mi respuesta en https://github.com/davidlealo/practicos_sisrec_2026/blob/main/practico04/04_content_based_texto_rspuestaDLO.ipynb
